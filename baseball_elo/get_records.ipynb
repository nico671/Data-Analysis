# %%
from enum import Enum

# %%
class BREFTeams(Enum):
    ANGELS = "ANA"
    DIAMONDBACKS = "ARI"
    BRAVES = "ATL"
    ORIOLES = "BAL"
    RED_SOX = "BOS"
    CUBS = "CHC"
    WHITE_SOX = "CHW"
    REDS = "CIN"
    GUARDIANS = "CLE"
    ROCKIES = "COL"
    TIGERS = "DET"
    MARLINS = "FLA"
    ASTROS = "HOU"
    ROYALS = "KCR"
    DODGERS = "LAD"
    BREWERS = "MIL"
    TWINS = "MIN"
    METS = "NYM"
    YANKEES = "NYY"
    ATHLETICS = "OAK"
    PHILLIES = "PHI"
    PIRATES = "PIT"
    PADRES = "SDP"
    MARINERS = "SEA"
    GIANTS = "SFG"
    CARDINALS = "STL"
    RAYS = "TBD"
    RANGERS = "TEX"
    BLUE_JAYS = "TOR"
    NATIONALS = "WSN"

    @classmethod
    def show_options(cls):
        return "\n".join([f"{team.name}: {team.value}" for team in cls])

# %%
import nest_asyncio

nest_asyncio.apply()  # patch asyncio to allow nested loops in notebooks

# %%
BREF_TEAM_RECORD_URL = "https://www.baseball-reference.com/teams/{team_code}/"

# %%
import asyncio

from bs4 import BeautifulSoup
from playwright.async_api import async_playwright

# %%
async def fetch_baseball_page(url: str) -> str:
    """
    Fetches the full HTML of a Baseball Reference page using Playwright
    (bypasses Cloudflare JavaScript challenge).
    """
    async with async_playwright() as p:
        browser = await p.chromium.launch(headless=True)
        page = await browser.new_page()
        await page.goto(url)
        # Wait until network is idle (all JS/XHRs done)
        await page.wait_for_load_state("networkidle")
        html = await page.content()
        await browser.close()
        return html

# %%
url = "https://www.baseball-reference.com/teams/NYY/"

# %%
html = asyncio.run(fetch_baseball_page(url))
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# Cell In[103], line 1
# ----> 1 html = asyncio.run(fetch_baseball_page(url))
#
# File ~/Documents/dev/data_analysis/.venv/lib/python3.13/site-packages/nest_asyncio.py:30, in _patch_asyncio.<locals>.run(main, debug)
#      28 task = asyncio.ensure_future(main)
#      29 try:
# ---> 30     return loop.run_until_complete(task)
#      31 finally:
#      32     if not task.done():
#
# File ~/Documents/dev/data_analysis/.venv/lib/python3.13/site-packages/nest_asyncio.py:98, in _patch_loop.<locals>.run_until_complete(self, future)
#      95 if not f.done():
#      96     raise RuntimeError(
#      97         'Event loop stopped before Future completed.')
# ---> 98 return f.result()
#
# File ~/.local/share/uv/python/cpython-3.13.5-macos-aarch64-none/lib/python3.13/asyncio/futures.py:199, in Future.result(self)
#     197 self.__log_traceback = False
#     198 if self._exception is not None:
# --> 199     raise self._exception.with_traceback(self._exception_tb)
#     200 return self._result
#
# File ~/.local/share/uv/python/cpython-3.13.5-macos-aarch64-none/lib/python3.13/asyncio/tasks.py:304, in Task.__step_run_and_handle_result(***failed resolving arguments***)
#     300 try:
#     301     if exc is None:
#     302         # We use the `send` method directly, because coroutines
#     303         # don't have `__iter__` and `__next__` methods.
# --> 304         result = coro.send(None)
#     305     else:
#     306         result = coro.throw(exc)
#
# Cell In[101], line 11, in fetch_baseball_page(url)
#       9 await page.goto(url)
#      10 # Wait until network is idle (all JS/XHRs done)
# ---> 11 await page.wait_for_load_state("networkidle")
#      12 html = await page.content()
#      13 await browser.close()
#
# File ~/Documents/dev/data_analysis/.venv/lib/python3.13/site-packages/playwright/async_api/_generated.py:9088, in Page.wait_for_load_state(self, state, timeout)
#    9036 async def wait_for_load_state(
#    9037     self,
#    9038     state: typing.Optional[
#    (...)   9042     timeout: typing.Optional[float] = None,
#    9043 ) -> None:
#    9044     """Page.wait_for_load_state
#    9045
#    9046     Returns when the required load state has been reached.
#    (...)   9084         `page.set_default_timeout()` methods.
#    9085     """
#    9087     return mapping.from_maybe_impl(
# -> 9088         await self._impl_obj.wait_for_load_state(state=state, timeout=timeout)
#    9089     )
#
# File ~/Documents/dev/data_analysis/.venv/lib/python3.13/site-packages/playwright/_impl/_page.py:576, in Page.wait_for_load_state(self, state, timeout)
#     571 async def wait_for_load_state(
#     572     self,
#     573     state: Literal["domcontentloaded", "load", "networkidle"] = None,
#     574     timeout: float = None,
#     575 ) -> None:
# --> 576     return await self._main_frame.wait_for_load_state(**locals_to_params(locals()))
#
# File ~/Documents/dev/data_analysis/.venv/lib/python3.13/site-packages/playwright/_impl/_frame.py:273, in Frame.wait_for_load_state(self, state, timeout)
#     268 async def wait_for_load_state(
#     269     self,
#     270     state: Literal["domcontentloaded", "load", "networkidle"] = None,
#     271     timeout: float = None,
#     272 ) -> None:
# --> 273     return await self._wait_for_load_state_impl(state, timeout)
#
# File ~/Documents/dev/data_analysis/.venv/lib/python3.13/site-packages/playwright/_impl/_frame.py:301, in Frame._wait_for_load_state_impl(self, state, timeout)
#     294         return actual_state == state
#     296     waiter.wait_for_event(
#     297         self._event_emitter,
#     298         "loadstate",
#     299         handle_load_state_event,
#     300     )
# --> 301 await waiter.result()
#
# File ~/.local/share/uv/python/cpython-3.13.5-macos-aarch64-none/lib/python3.13/asyncio/futures.py:286, in Future.__await__(self)
#     284 if not self.done():
#     285     self._asyncio_future_blocking = True
# --> 286     yield self  # This tells Task to wait for completion.
#     287 if not self.done():
#     288     raise RuntimeError("await wasn't used with future")
#
# File ~/.local/share/uv/python/cpython-3.13.5-macos-aarch64-none/lib/python3.13/asyncio/tasks.py:375, in Task.__wakeup(self, future)
#     373 def __wakeup(self, future):
#     374     try:
# --> 375         future.result()
#     376     except BaseException as exc:
#     377         # This may also be a cancellation.
#     378         self.__step(exc)
#
# File ~/.local/share/uv/python/cpython-3.13.5-macos-aarch64-none/lib/python3.13/asyncio/futures.py:199, in Future.result(self)
#     197 self.__log_traceback = False
#     198 if self._exception is not None:
# --> 199     raise self._exception.with_traceback(self._exception_tb)
#     200 return self._result
#
# TimeoutError: Timeout 30000ms exceeded.

# %%
soup = BeautifulSoup(html, "html.parser")

# %%
print("Page Title:", soup.title.string)
# Out:
# Page Title: New York Yankees Team History & Encyclopedia | Baseball-Reference.com

# %%
franch_history_table = soup.find("table", {"id": "franchise_years"})

# %%
franch_history_table
# Out:
# <table class="sortable stats_table now_sortable sticky_table eq1 re1 le1" data-cols-to-freeze=",1" id="franchise_years">
# <caption>Franchise History</caption>
# <colgroup><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/></colgroup>
# <thead>
# <tr>
# <th aria-label="Year" class="poptip sort_default_asc show_partial_when_sorting left" data-stat="year_ID" data-tip="A Star indicates an all-star that season.&lt;br&gt;A Ring indicates the player appeared in WS for winning team." scope="col">Year</th>
# <th aria-label="Tm" class="poptip sort_default_asc left" data-stat="team_name" scope="col">Tm</th>
# <th aria-label="Lg" class="poptip sort_default_asc center" data-stat="lg_ID" data-tip="&lt;strong&gt;League&lt;/strong&gt;&lt;br&gt; &lt;strong&gt;AL&lt;/strong&gt; - American League (1901-present)&lt;br&gt; &lt;strong&gt;NL&lt;/strong&gt; - National League (1876-present)&lt;br&gt; &lt;strong&gt;AA&lt;/strong&gt; - American Association (1882-1891)&lt;br&gt; &lt;strong&gt;UA&lt;/strong&gt; - Union Association (1884)&lt;br&gt; &lt;strong&gt;PL&lt;/strong&gt; - Players League (1890)&lt;br&gt; &lt;strong&gt;FL&lt;/strong&gt; - Federal League (1914-1915)&lt;br&gt; &lt;strong&gt;NA&lt;/strong&gt; - National Association (1871-1875)&lt;br&gt; &lt;strong&gt;ANL&lt;/strong&gt; - American Negro League (1929)&lt;br&gt; &lt;strong&gt;ECL&lt;/strong&gt; - Eastern Colored League (1923-1928)&lt;br&gt; &lt;strong&gt;EWL&lt;/strong&gt; - East-West League (1932)&lt;br&gt; &lt;strong&gt;NAL&lt;/strong&gt; - Negro American League (1937-1948)&lt;br&gt; &lt;strong&gt;NNL&lt;/strong&gt; - Negro National League (1920-1931)&lt;br&gt; &lt;strong&gt;NN2&lt;/strong&gt; - Negro National League 2 (1933-1948)&lt;br&gt; &lt;strong&gt;NSL&lt;/strong&gt; - Negro Southern League (1932)" scope="col">Lg</th>
# <th aria-label="Games Played" class="poptip center" data-stat="G" data-tip="Games Played or Pitched" scope="col">G</th>
# <th aria-label="Wins" class="poptip center" data-stat="W" data-tip="Wins" scope="col">W</th>
# <th aria-label="Losses" class="poptip center" data-stat="L" data-tip="Losses" scope="col">L</th>
# <th aria-label="Ties" class="poptip center" data-stat="ties" data-tip="&lt;strong&gt;Ties&lt;/strong&gt;&lt;br&gt;Prior to lights and tarps it was common for games&lt;br&gt; to be called on account of darkness or rain&lt;br&gt;and then replayed in full at a later date.&lt;br&gt;Game stats from ties still counted.&lt;br&gt;Some leagues also do not play unlimited numbers of innings." scope="col">Ties</th>
# <th aria-label="Win-Loss %" class="poptip hide_non_quals center" data-filter="1" data-name="Win-Loss %" data-stat="win_loss_perc" data-tip="&lt;strong&gt;Win-Loss Percentage&lt;/strong&gt;&lt;br&gt;W / (W + L)&lt;br&gt;For players, leaders need one decision for every ten team games.&lt;br&gt;For managers, minimum to qualify for leading is 320 games." scope="col">W-L%</th>
# <th aria-label="PythW-L%" class="poptip center" data-filter="1" data-name="PythW-L%" data-stat="win_loss_perc_pythag" data-tip="&lt;strong&gt;Pythagorean Win-Loss Percentage&lt;/strong&gt;&lt;br&gt;This value is an estimate of the teams win-loss percentage&lt;br&gt;based on the runs scored and runs allowed by this team." scope="col">pythW-L%</th>
# <th aria-label="Finish" class="poptip sort_default_asc show_partial_when_sorting center" data-stat="finish" data-tip="Team&amp;#x2019;s Finish&lt;br&gt;For career totals these are the average of all &lt;br&gt;years weighted by the number games played or managed. " scope="col">Finish</th>
# <th aria-label="Games Back" class="poptip sort_default_asc center" data-stat="games_back" data-tip="&lt;strong&gt;Games Back of Division/League Leader&lt;/strong&gt;&lt;br&gt;Computed as games over .500 of leader (W-L) minus games over .500 of team divided by two.&lt;br&gt;Typically computed at the end of play for a particular day.&lt;br&gt;Blank for 1st game of DH." scope="col">GB</th>
# <th aria-label="Playoffs" class="poptip center" data-stat="playoffs" data-tip="&lt;strong&gt;Playoffs&lt;/strong&gt;&lt;br&gt;This shows either the farthest each team went into the postseason&lt;br&gt;or how many postseason appearances in team history." scope="col">Playoffs</th>
# <th aria-label="Runs Scored" class="poptip center" data-stat="R" data-tip="Runs Scored/Allowed" scope="col">R</th>
# <th aria-label="Runs Allowed" class="poptip center" data-stat="RA" data-tip="Runs Allowed" scope="col">RA</th>
# <th aria-label="Attendance" class="poptip center" data-stat="attendance" data-tip="&lt;strong&gt;Attendance&lt;/strong&gt;&lt;br&gt;Typically, tickets sold in home games." scope="col">Attendance</th>
# <th aria-label="BatAge" class="poptip sort_default_asc center" data-stat="age_bat" data-tip="&lt;strong&gt;Batters&amp;#x2019; average age&lt;/strong&gt;&lt;br&gt;Weighted by AB + Games Played" scope="col">BatAge</th>
# <th aria-label="PAge" class="poptip sort_default_asc center" data-stat="age_pit" data-tip="&lt;strong&gt;Pitchers&amp;#x2019; average age&lt;/strong&gt;&lt;br&gt;Weighted by 3*GS + G + SV" scope="col">PAge</th>
# <th aria-label="#Bat" class="poptip center" data-stat="batters_used" data-tip="&lt;strong&gt;Number of Players used in Games&lt;/strong&gt;" scope="col">#Bat</th>
# <th aria-label="#P" class="poptip center" data-stat="pitchers_used" data-tip="&lt;strong&gt;Number of Pitchers used in Games&lt;/strong&gt;" scope="col">#P</th>
# <th aria-label="Top Player" class="poptip center" data-stat="war_leader" data-tip="The team leader for this season in Wins above Replacement" scope="col">Top Player</th>
# <th aria-label="Managers" class="poptip sort_default_asc center" data-stat="managers" scope="col">Managers</th>
# </tr>
# </thead>
# <tbody><tr data-row="0"><th class="left" data-stat="year_ID" scope="row"><a href="/teams/NYY/2025.shtml">2025</a></th><td class="left" data-stat="team_name"><a href="/teams/NYY/2025.shtml">New York Yankees</a></td><td class="left" data-stat="lg_ID"><a href="/leagues/AL/2025.shtml">AL East</a></td><td class="right" data-stat="G">132</td><td class="right" data-stat="W">72</td><td class="right" data-stat="L">60</td><td class="right iz" data-stat="ties">0</td><td class="right" data-stat="win_loss_perc">.545</td><td class="right" data-stat="win_loss_perc_pythag">.580</td><td class="right" csk="3" data-stat="finish">3rd of 5</td><td class="right" csk="4.5" data-stat="games_back">4.5</td><td class="right iz" csk="0" data-stat="playoffs"></td><td class="right" data-stat="R">681</td><td class="right" data-stat="RA">571</td><td class="right" data-stat="attendance">2,859,427</td><td class="right" data-stat="age_bat">28.5</td><td class="right" data-stat="age_pit">30.7</td><td class="right" data-stat="batters_used">52</td><td class="right" data-stat="pitchers_used">33</td><td class="left" csk="6.8" data-stat="war_leader"><a href="/players/j/judgeaa01.shtml" title="Aaron Judge">A.Judge</a> (6.8)</td><td class="left" data-stat="managers"><a href="/managers/booneaa01.shtml" title="Aaron Boone">A.Boone</a> (72-60)</td></tr>
# <tr data-row="1"><th class="left" data-stat="year_ID" scope="row"><a href="/teams/NYY/2024.shtml">2024</a></th><td class="left" data-stat="team_name"><a href="/teams/NYY/2024.shtml">New York Yankees</a></td><td class="left" data-stat="lg_ID"><a href="/leagues/AL/2024.shtml">AL East</a></td><td class="right" data-stat="G">162</td><td class="right" data-stat="W">94</td><td class="right" data-stat="L">68</td><td class="right iz" data-stat="ties">0</td><td class="right" data-stat="win_loss_perc">.580</td><td class="right" data-stat="win_loss_perc_pythag">.590</td><td class="right" csk="1" data-stat="finish">1st of 5</td><td class="right" csk="0.0" data-stat="games_back">--</td><td class="right" csk="8" data-stat="playoffs"><a href="/postseason/2024_WS.shtml">Lost WS (4-1)</a></td><td class="right" data-stat="R">815</td><td class="right" data-stat="RA">668</td><td class="right" data-stat="attendance">3,309,838</td><td class="right" data-stat="age_bat">28.0</td><td class="right" data-stat="age_pit">30.1</td><td class="right" data-stat="batters_used">54</td><td class="right" data-stat="pitchers_used">33</td><td class="left" csk="10.8" data-stat="war_leader"><a href="/players/j/judgeaa01.shtml" title="Aaron Judge">A.Judge</a> (10.8)</td><td class="left" data-stat="managers"><a href="/managers/booneaa01.shtml" title="Aaron Boone">A.Boone</a> (94-68)</td></tr>
# <tr data-row="2"><th class="left" data-stat="year_ID" scope="row"><a href="/teams/NYY/2023.shtml">2023</a></th><td class="left" data-stat="team_name"><a href="/teams/NYY/2023.shtml">New York Yankees</a></td><td class="left" data-stat="lg_ID"><a href="/leagues/AL/2023.shtml">AL East</a></td><td class="right" data-stat="G">162</td><td class="right" data-stat="W">82</td><td class="right" data-stat="L">80</td><td class="right iz" data-stat="ties">0</td><td class="right" data-stat="win_loss_perc">.506</td><td class="right" data-stat="win_loss_perc_pythag">.483</td><td class="right" csk="4" data-stat="finish">4th of 5</td><td class="right" csk="19.0" data-stat="games_back">19.0</td><td class="right iz" csk="0" data-stat="playoffs"></td><td class="right" data-stat="R">673</td><td class="right" data-stat="RA">698</td><td class="right" data-stat="attendance">3,269,016</td><td class="right" data-stat="age_bat">28.5</td><td class="right" data-stat="age_pit">29.1</td><td class="right" data-stat="batters_used">54</td><td class="right" data-stat="pitchers_used">32</td><td class="left" csk="7.4" data-stat="war_leader"><a href="/players/c/colege01.shtml" title="Gerrit Cole">G.Cole</a> (7.4)</td><td class="left" data-stat="managers"><a href="/managers/booneaa01.shtml" title="Aaron Boone">A.Boone</a> (82-80)</td></tr>
# <tr data-row="3"><th class="left" data-stat="year_ID" scope="row"><a href="/teams/NYY/2022.shtml">2022</a></th><td class="left" data-stat="team_name"><a href="/teams/NYY/2022.shtml">New York Yankees</a></td><td class="left" data-stat="lg_ID"><a href="/leagues/AL/2022.shtml">AL East</a></td><td class="right" data-stat="G">162</td><td class="right" data-stat="W">99</td><td class="right" data-stat="L">63</td><td class="right iz" data-stat="ties">0</td><td class="right" data-stat="win_loss_perc">.611</td><td class="right" data-stat="win_loss_perc_pythag">.656</td><td class="right" csk="1" data-stat="finish">1st of 5</td><td class="right" csk="0.0" data-stat="games_back">--</td><td class="right" csk="6" data-stat="playoffs"><a href="/postseason/2022_ALCS.shtml">Lost ALCS (4-0)</a></td><td class="right" data-stat="R">807</td><td class="right" data-stat="RA">567</td><td class="right" data-stat="attendance">3,136,207</td><td class="right" data-stat="age_bat">30.3</td><td class="right" data-stat="age_pit">29.2</td><td class="right" data-stat="batters_used">54</td><td class="right" data-stat="pitchers_used">33</td><td class="left" csk="10.8" data-stat="war_leader"><a href="/players/j/judgeaa01.shtml" title="Aaron Judge">A.Judge</a> (10.8)</td><td class="left" data-stat="managers"><a href="/managers/booneaa01.shtml" title="Aaron Boone">A.Boone</a> (99-63)</td></tr>
# <tr data-row="4"><th class="left" data-stat="year_ID" scope="row"><a href="/teams/NYY/2021.shtml">2021</a></th><td class="left" data-stat="team_name"><a href="/teams/NYY/2021.shtml">New York Yankees</a></td><td class="left" data-stat="lg_ID"><a href="/leagues/AL/2021.shtml">AL East</a></td><td class="right" data-stat="G">162</td><td class="right" data-stat="W">92</td><td class="right" data-stat="L">70</td><td class="right iz" data-stat="ties">0</td><td class="right" data-stat="win_loss_perc">.568</td><td class="right" data-stat="win_loss_perc_pythag">.528</td><td class="right" csk="2" data-stat="finish">2nd of 5</td><td class="right" csk="8.0" data-stat="games_back">8.0</td><td class="right" csk="2" data-stat="playoffs"><a href="/postseason/2021_ALWC.shtml">Lost ALWC (1-0)</a></td><td class="right" data-stat="R">711</td><td class="right" data-stat="RA">669</td><td class="right" data-stat="attendance">1,959,854</td><td class="right" data-stat="age_bat">29.3</td><td class="right" data-stat="age_pit">29.3</td><td class="right" data-stat="batters_used">59</td><td class="right" data-stat="pitchers_used">30</td><td class="left" csk="5.9" data-stat="war_leader"><a href="/players/j/judgeaa01.shtml" title="Aaron Judge">A.Judge</a> (5.9)</td><td class="left" data-stat="managers"><a href="/managers/booneaa01.shtml" title="Aaron Boone">A.Boone</a> (92-70)</td></tr>
# <tr data-row="5"><th class="left" data-stat="year_ID" scope="row"><a href="/teams/NYY/2020.shtml">2020</a></th><td class="left" data-stat="team_name"><a href="/teams/NYY/2020.shtml">New York Yankees</a></td><td class="left" data-stat="lg_ID"><a href="/leagues/AL/2020.shtml">AL East</a></td><td class="right" data-stat="G">60</td><td class="right" data-stat="W">33</td><td class="right" data-stat="L">27</td><td class="right iz" data-stat="ties">0</td><td class="right" data-stat="win_loss_perc">.550</td><td class="right" data-stat="win_loss_perc_pythag">.570</td><td class="right" csk="2" data-stat="finish">2nd of 5</td><td class="right" csk="7.0" data-stat="games_back">7.0</td><td class="right" csk="4" data-stat="playoffs"><a href="/postseason/2020_ALDS1.shtml">Lost ALDS (3-2)</a></td><td class="right" data-stat="R">315</td><td class="right" data-stat="RA">270</td><td class="right iz" data-stat="attendance"></td><td class="right" data-stat="age_bat">28.5</td><td class="right" data-stat="age_pit">29.2</td><td class="right" data-stat="batters_used">43</td><td class="right" data-stat="pitchers_used">25</td><td class="left" csk="3.0" data-stat="war_leader"><a href="/players/l/lemahdj01.shtml" title="DJ LeMahieu">D.LeMahieu</a> (3.0)</td><td class="left" data-stat="managers"><a href="/managers/booneaa01.shtml" title="Aaron Boone">A.Boone</a> (33-27)</td></tr>
# <tr data-row="6"><th class="left" data-stat="year_ID" scope="row"><a href="/teams/NYY/2019.shtml">2019</a></th><td class="left" data-stat="team_name"><a href="/teams/NYY/2019.shtml">New York Yankees</a></td><td class="left" data-stat="lg_ID"><a href="/leagues/AL/2019.shtml">AL East</a></td><td class="right" data-stat="G">162</td><td class="right" data-stat="W">103</td><td class="right" data-stat="L">59</td><td class="right iz" data-stat="ties">0</td><td class="right" data-stat="win_loss_perc">.636</td><td class="right" data-stat="win_loss_perc_pythag">.610</td><td class="right" csk="1" data-stat="finish">1st of 5</td><td class="right" csk="0.0" data-stat="games_back">--</td><td class="right" csk="6" data-stat="playoffs"><a href="/postseason/2019_ALCS.shtml">Lost ALCS (4-2)</a></td><td class="right" data-stat="R">943</td><td class="right" data-stat="RA">739</td><td class="right" data-stat="attendance">3,304,404</td><td class="right" data-stat="age_bat">28.3</td><td class="right" data-stat="age_pit">30.2</td><td class="right" data-stat="batters_used">54</td><td class="right" data-stat="pitchers_used">33</td><td class="left" csk="5.6" data-stat="war_leader"><a href="/players/j/judgeaa01.shtml" title="Aaron Judge">A.Judge</a> (5.6)</td><td class="left" data-stat="managers"><a href="/managers/booneaa01.shtml" title="Aaron Boone">A.Boone</a> (103-59)</td></tr>
# <tr data-row="7"><th class="left" data-stat="year_ID" scope="row"><a href="/teams/NYY/2018.shtml">2018</a></th><td class="left" data-stat="team_name"><a href="/teams/NYY/2018.shtml">New York Yankees</a></td><td class="left" data-stat="lg_ID"><a href="/leagues/AL/2018.shtml">AL East</a></td><td class="right" data-stat="G">162</td><td class="right" data-stat="W">100</td><td class="right" data-stat="L">62</td><td class="right iz" data-stat="ties">0</td><td class="right" data-stat="win_loss_perc">.617</td><td class="right" data-stat="win_loss_perc_pythag">.608</td><td class="right" csk="2" data-stat="finish">2nd of 5</td><td class="right" csk="8.0" data-stat="games_back">8.0</td><td class="right" csk="4" data-stat="playoffs"><a href="/postseason/2018_ALDS1.shtml">Lost ALDS (3-1)</a></td><td class="right" data-stat="R">851</td><td class="right" data-stat="RA">669</td><td class="right" data-stat="attendance">3,482,855</td><td class="right" data-stat="age_bat">27.2</td><td class="right" data-stat="age_pit">28.8</td><td class="right" data-stat="batters_used">49</td><td class="right" data-stat="pitchers_used">27</td><td class="left" csk="6.0" data-stat="war_leader"><a href="/players/j/judgeaa01.shtml" title="Aaron Judge">A.Judge</a> (6.0)</td><td class="left" data-stat="managers"><a href="/managers/booneaa01.shtml" title="Aaron Boone">A.Boone</a> (100-62)</td></tr>
# <tr data-row="8"><th class="left" data-stat="year_ID" scope="row"><a href="/teams/NYY/2017.shtml">2017</a></th><td class="left" data-stat="team_name"><a href="/teams/NYY/2017.shtml">New York Yankees</a></td><td class="left" data-stat="lg_ID"><a href="/leagues/AL/2017.shtml">AL East</a></td><td class="right" data-stat="G">162</td><td class="right" data-stat="W">91</td><td class="right" data-stat="L">71</td><td class="right iz" data-stat="ties">0</td><td class="right" data-stat="win_loss_perc">.562</td><td class="right" data-stat="win_loss_perc_pythag">.618</td><td class="right" csk="2" data-stat="finish">2nd of 5</td><td class="right" csk="2.0" data-stat="games_back">2.0</td><td class="right" csk="6" data-stat="playoffs"><a href="/postseason/2017_ALCS.shtml">Lost ALCS (4-3)</a></td><td class="right" data-stat="R">858</td><td class="right" data-stat="RA">660</td><td class="right" data-stat="attendance">3,154,938</td><td class="right" data-stat="age_bat">28.6</td><td class="right" data-stat="age_pit">27.8</td><td class="right" data-stat="batters_used">51</td><td class="right" data-stat="pitchers_used">25</td><td class="left" csk="8.1" data-stat="war_leader"><a href="/players/j/judgeaa01.shtml" title="Aaron Judge">A.Judge</a> (8.1)</td><td class="left" data-stat="managers"><a href="/managers/girarjo01.shtml" title="Joe Girardi">J.Girardi</a> (91-71)</td></tr>
# <tr data-row="9"><th class="left" data-stat="year_ID" scope="row"><a href="/teams/NYY/2016.shtml">2016</a></th><td class="left" data-stat="team_name"><a href="/teams/NYY/2016.shtml">New York Yankees</a></td><td class="left" data-stat="lg_ID"><a href="/leagues/AL/2016.shtml">AL East</a></td><td class="right" data-stat="G">162</td><td class="right" data-stat="W">84</td><td class="right" data-stat="L">78</td><td class="right iz" data-stat="ties">0</td><td class="right" data-stat="win_loss_perc">.519</td><td class="right" data-stat="win_loss_perc_pythag">.485</td><td class="right" csk="4" data-stat="finish">4th of 5</td><td class="right" csk="9.0" data-stat="games_back">9.0</td><td class="right iz" csk="0" data-stat="playoffs"></td><td class="right" data-stat="R">680</td><td class="right" data-stat="RA">702</td><td class="right" data-stat="attendance">3,063,405</td><td class="right" data-stat="age_bat">30.1</td><td class="right" data-stat="age_pit">27.9</td><td class="right" data-stat="batters_used">53</td><td class="right" data-stat="pitchers_used">29</td><td class="left" csk="5.1" data-stat="war_leader"><a href="/players/t/tanakma01.shtml" title="Masahiro Tanaka">M.Tanaka</a> (5.1)</td><td class="left" data-stat="managers"><a href="/managers/girarjo01.shtml" title="Joe Girardi">J.Girardi</a> (84-78)</td></tr>
# <tr data-row="10"><th class="left" data-stat="year_ID" scope="row"><a href="/teams/NYY/2015.shtml">2015</a></th><td class="left" data-stat="team_name"><a href="/teams/NYY/2015.shtml">New York Yankees</a></td><td class="left" data-stat="lg_ID"><a href="/leagues/AL/2015.shtml">AL East</a></td><td class="right" data-stat="G">162</td><td class="right" data-stat="W">87</td><td class="right" data-stat="L">75</td><td class="right iz" data-stat="ties">0</td><td class="right" data-stat="win_loss_perc">.537</td><td class="right" data-stat="win_loss_perc_pythag">.541</td><td class="right" csk="2" data-stat="finish">2nd of 5</td><td class="right" csk="6.0" data-stat="games_back">6.0</td><td class="right" csk="2" data-stat="playoffs"><a href="/postseason/2015_ALWC.shtml">Lost ALWC (1-0)</a></td><td class="right" data-stat="R">764</td><td class="right" data-stat="RA">698</td><td class="right" data-stat="attendance">3,193,795</td><td class="right" data-stat="age_bat">31.4</td><td class="right" data-stat="age_pit">27.4</td><td class="right" data-stat="batters_used">56</td><td class="right" data-stat="pitchers_used">33</td><td class="left" csk="3.9" data-stat="war_leader"><a href="/players/b/betande01.shtml" title="Dellin Betances">D.Betances</a> (3.9)</td><td class="left" data-stat="managers"><a href="/managers/girarjo01.shtml" title="Joe Girardi">J.Girardi</a> (87-75)</td></tr>
# <tr data-row="11"><th class="left" data-stat="year_ID" scope="row"><a href="/teams/NYY/2014.shtml">2014</a></th><td class="left" data-stat="team_name"><a href="/teams/NYY/2014.shtml">New York Yankees</a></td><td class="left" data-stat="lg_ID"><a href="/leagues/AL/2014.shtml">AL East</a></td><td class="right" data-stat="G">162</td><td class="right" data-stat="W">84</td><td class="right" data-stat="L">78</td><td class="right iz" data-stat="ties">0</td><td class="right" data-stat="win_loss_perc">.519</td><td class="right" data-stat="win_loss_perc_pythag">.478</td><td class="right" csk="2" data-stat="finish">2nd of 5</td><td class="right" csk="12.0" data-stat="games_back">12.0</td><td class="right iz" csk="0" data-stat="playoffs"></td><td class="right" data-stat="R">633</td><td class="right" data-stat="RA">664</td><td class="right" data-stat="attendance">3,401,624</td><td class="right" data-stat="age_bat">32.8</td><td class="right" data-stat="age_pit">29.3</td><td class="right" data-stat="batters_used">58</td><td class="right" data-stat="pitchers_used">33</td><td class="left" csk="3.8" data-stat="war_leader"><a href="/players/g/gardnbr01.shtml" title="Brett Gardner">B.Gardner</a> (3.8)</td><td class="left" data-stat="managers"><a href="/managers/girarjo01.shtml" title="Joe Girardi">J.Girardi</a> (84-78)</td></tr>
# <tr data-row="12"><th class="left" data-stat="year_ID" scope="row"><a href="/teams/NYY/2013.shtml">2013</a></th><td class="left" data-stat="team_name"><a href="/teams/NYY/2013.shtml">New York Yankees</a></td><td class="left" data-stat="lg_ID"><a href="/leagues/AL/2013.shtml">AL East</a></td><td class="right" data-stat="G">162</td><td class="right" data-stat="W">85</td><td class="right" data-stat="L">77</td><td class="right iz" data-stat="ties">0</td><td class="right" data-stat="win_loss_perc">.525</td><td class="right" data-stat="win_loss_perc_pythag">.485</td><td class="right" csk="3" data-stat="finish">3rd of 5</td><td class="right" csk="12.0" data-stat="games_back">12.0</td><td class="right iz" csk="0" data-stat="playoffs"></td><td class="right" data-stat="R">650</td><td class="right" data-stat="RA">671</td><td class="right" data-stat="attendance">3,279,589</td><td class="right" data-stat="age_bat">31.9</td><td class="right" data-stat="age_pit">31.8</td><td class="right" data-stat="batters_used">56</td><td class="right" data-stat="pitchers_used">24</td><td class="left" csk="6.6" data-stat="war_leader"><a href="/players/c/canoro01.shtml" title="Robinson Canó">R.Canó</a> (6.6)</td><td class="left" data-stat="managers"><a href="/managers/girarjo01.shtml" title="Joe Girardi">J.Girardi</a> (85-77)</td></tr>
# <tr data-row="13"><th class="left" data-stat="year_ID" scope="row"><a href="/teams/NYY/2012.shtml">2012</a></th><td class="left" data-stat="team_name"><a href="/teams/NYY/2012.shtml">New York Yankees</a></td><td class="left" data-stat="lg_ID"><a href="/leagues/AL/2012.shtml">AL East</a></td><td class="right" data-stat="G">162</td><td class="right" data-stat="W">95</td><td class="right" data-stat="L">67</td><td class="right iz" data-stat="ties">0</td><td class="right" data-stat="win_loss_perc">.586</td><td class="right" data-stat="win_loss_perc_pythag">.584</td><td class="right" csk="1" data-stat="finish">1st of 5</td><td class="right" csk="0.0" data-stat="games_back">--</td><td class="right" csk="6" data-stat="playoffs"><a href="/postseason/2012_ALCS.shtml">Lost ALCS (4-0)</a></td><td class="right" data-stat="R">804</td><td class="right" data-stat="RA">668</td><td class="right" data-stat="attendance">3,542,406</td><td class="right" data-stat="age_bat">32.9</td><td class="right" data-stat="age_pit">30.3</td><td class="right" data-stat="batters_used">45</td><td class="right" data-stat="pitchers_used">24</td><td class="left" csk="8.4" data-stat="war_leader"><a href="/players/c/canoro01.shtml" title="Robinson Canó">R.Canó</a> (8.4)</td><td class="left" data-stat="managers"><a href="/managers/girarjo01.shtml" title="Joe Girardi">J.Girardi</a> (95-67)</td></tr>
# <tr data-row="14"><th class="left" data-stat="year_ID" scope="row"><a href="/teams/NYY/2011.shtml">2011</a></th><td class="left" data-stat="team_name"><a href="/teams/NYY/2011.shtml">New York Yankees</a></td><td class="left" data-stat="lg_ID"><a href="/leagues/AL/2011.shtml">AL East</a></td><td class="right" data-stat="G">162</td><td class="right" data-stat="W">97</td><td class="right" data-stat="L">65</td><td class="right iz" data-stat="ties">0</td><td class="right" data-stat="win_loss_perc">.599</td><td class="right" data-stat="win_loss_perc_pythag">.624</td><td class="right" csk="1" data-stat="finish">1st of 5</td><td class="right" csk="0.0" data-stat="games_back">--</td><td class="right" csk="4" data-stat="playoffs"><a href="/postseason/2011_ALDS1.shtml">Lost ALDS (3-2)</a></td><td class="right" data-stat="R">867</td><td class="right" data-stat="RA">657</td><td class="right" data-stat="attendance">3,653,680</td><td class="right" data-stat="age_bat">30.6</td><td class="right" data-stat="age_pit">31.0</td><td class="right" data-stat="batters_used">48</td><td class="right" data-stat="pitchers_used">28</td><td class="left" csk="6.4" data-stat="war_leader"><a href="/players/s/sabatc.01.shtml" title="CC Sabathia">C.Sabathia</a> (6.4)</td><td class="left" data-stat="managers"><a href="/managers/girarjo01.shtml" title="Joe Girardi">J.Girardi</a> (97-65)</td></tr>
# <tr data-row="15"><th class="left" data-stat="year_ID" scope="row"><a href="/teams/NYY/2010.shtml">2010</a></th><td class="left" data-stat="team_name"><a href="/teams/NYY/2010.shtml">New York Yankees</a></td><td class="left" data-stat="lg_ID"><a href="/leagues/AL/2010.shtml">AL East</a></td><td class="right" data-stat="G">162</td><td class="right" data-stat="W">95</td><td class="right" data-stat="L">67</td><td class="right iz" data-stat="ties">0</td><td class="right" data-stat="win_loss_perc">.586</td><td class="right" data-stat="win_loss_perc_pythag">.597</td><td class="right" csk="2" data-stat="finish">2nd of 5</td><td class="right" csk="1.0" data-stat="games_back">1.0</td><td class="right" csk="6" data-stat="playoffs"><a href="/postseason/2010_ALCS.shtml">Lost ALCS (4-2)</a></td><td class="right" data-stat="R">859</td><td class="right" data-stat="RA">693</td><td class="right" data-stat="attendance">3,765,807</td><td class="right" data-stat="age_bat">30.4</td><td class="right" data-stat="age_pit">30.3</td><td class="right" data-stat="batters_used">43</td><td class="right" data-stat="pitchers_used">21</td><td class="left" csk="8.1" data-stat="war_leader"><a href="/players/c/canoro01.shtml" title="Robinson Canó">R.Canó</a> (8.1)</td><td class="left" data-stat="managers"><a href="/managers/girarjo01.shtml" title="Joe Girardi">J.Girardi</a> (95-67)</td></tr>
# <tr data-row="16"><th class="left" data-stat="year_ID" scope="row"><a href="/teams/NYY/2009.shtml">2009</a></th><td class="left" data-stat="team_name"><a href="/teams/NYY/2009.shtml">New York Yankees</a></td><td class="left" data-stat="lg_ID"><a href="/leagues/AL/2009.shtml">AL East</a></td><td class="right" data-stat="G">162</td><td class="right" data-stat="W">103</td><td class="right" data-stat="L">59</td><td class="right iz" data-stat="ties">0</td><td class="right" data-stat="win_loss_perc">.636</td><td class="right" data-stat="win_loss_perc_pythag">.588</td><td class="right" csk="1" data-stat="finish">1st of 5</td><td class="right" csk="0.0" data-stat="games_back">--</td><td class="right" csk="10" data-stat="playoffs"><strong><a href="/postseason/2009_WS.shtml">Won WS (4-2)</a></strong></td><td class="right" data-stat="R">915</td><td class="right" data-stat="RA">753</td><td class="right" data-stat="attendance">3,719,358</td><td class="right" data-stat="age_bat">30.7</td><td class="right" data-stat="age_pit">29.3</td><td class="right" data-stat="batters_used">45</td><td class="right" data-stat="pitchers_used">24</td><td class="left" csk="6.6" data-stat="war_leader"><a href="/players/j/jeterde01.shtml" title="Derek Jeter">D.Jeter</a> (6.6)</td><td class="left" data-stat="managers"><a href="/managers/girarjo01.shtml" title="Joe Girardi">J.Girardi</a> (103-59)</td></tr>
# <tr data-row="17"><th class="left" data-stat="year_ID" scope="row"><a href="/teams/NYY/2008.shtml">2008</a></th><td class="left" data-stat="team_name"><a href="/teams/NYY/2008.shtml">New York Yankees</a></td><td class="left" data-stat="lg_ID"><a href="/leagues/AL/2008.shtml">AL East</a></td><td class="right" data-stat="G">162</td><td class="right" data-stat="W">89</td><td class="right" data-stat="L">73</td><td class="right iz" data-stat="ties">0</td><td class="right" data-stat="win_loss_perc">.549</td><td class="right" data-stat="win_loss_perc_pythag">.537</td><td class="right" csk="3" data-stat="finish">3rd of 5</td><td class="right" csk="8.0" data-stat="games_back">8.0</td><td class="right iz" csk="0" data-stat="playoffs"></td><td class="right" data-stat="R">789</td><td class="right" data-stat="RA">727</td><td class="right" data-stat="attendance">4,298,655</td><td class="right" data-stat="age_bat">31.4</td><td class="right" data-stat="age_pit">30.6</td><td class="right" data-stat="batters_used">51</td><td class="right" data-stat="pitchers_used">27</td><td class="left" csk="6.8" data-stat="war_leader"><a href="/players/r/rodrial01.shtml" title="Alex Rodriguez">A.Rodriguez</a> (6.8)</td><td class="left" data-stat="managers"><a href="/managers/girarjo01.shtml" title="Joe Girardi">J.Girardi</a> (89-73)</td></tr>
# <tr data-row="18"><th class="left" data-stat="year_ID" scope="row"><a href="/teams/NYY/2007.shtml">2007</a></th><td class="left" data-stat="team_name"><a href="/teams/NYY/2007.shtml">New York Yankees</a></td><td class="left" data-stat="lg_ID"><a href="/leagues/AL/2007.shtml">AL East</a></td><td class="right" data-stat="G">162</td><td class="right" data-stat="W">94</td><td class="right" data-stat="L">68</td><td class="right iz" data-stat="ties">0</td><td class="right" data-stat="win_loss_perc">.580</td><td class="right" data-stat="win_loss_perc_pythag">.599</td><td class="right" csk="2" data-stat="finish">2nd of 5</td><td class="right" csk="2.0" data-stat="games_back">2.0</td><td class="right" csk="4" data-stat="playoffs"><a href="/postseason/2007_ALDS2.shtml">Lost ALDS (3-1)</a></td><td class="right" data-stat="R">968</td><td class="right" data-stat="RA">777</td><td class="right" data-stat="attendance">4,271,083</td><td class="right" data-stat="age_bat">30.8</td><td class="right" data-stat="age_pit">31.4</td><td class="right" data-stat="batters_used">49</td><td class="right" data-stat="pitchers_used">28</td><td class="left" csk="9.4" data-stat="war_leader"><a href="/players/r/rodrial01.shtml" title="Alex Rodriguez">A.Rodriguez</a> (9.4)</td><td class="left" data-stat="managers"><a href="/managers/torrejo01.shtml" title="Joe Torre">J.Torre</a> (94-68)</td></tr>
# <tr data-row="19"><th class="left" data-stat="year_ID" scope="row"><a href="/teams/NYY/2006.shtml">2006</a></th><td class="left" data-stat="team_name"><a href="/teams/NYY/2006.shtml">New York Yankees</a></td><td class="left" data-stat="lg_ID"><a href="/leagues/AL/2006.shtml">AL East</a></td><td class="right" data-stat="G">162</td><td class="right" data-stat="W">97</td><td class="right" data-stat="L">65</td><td class="right iz" data-stat="ties">0</td><td class="right" data-stat="win_loss_perc">.599</td><td class="right" data-stat="win_loss_perc_pythag">.587</td><td class="right" csk="1" data-stat="finish">1st of 5</td><td class="right" csk="0.0" data-stat="games_back">--</td><td class="right" csk="4" data-stat="playoffs"><a href="/postseason/2006_ALDS1.shtml">Lost ALDS (3-1)</a></td><td class="right" data-stat="R">930</td><td class="right" data-stat="RA">767</td><td class="right" data-stat="attendance">4,248,067</td><td class="right" data-stat="age_bat">30.9</td><td class="right" data-stat="age_pit">32.5</td><td class="right" data-stat="batters_used">49</td><td class="right" data-stat="pitchers_used">25</td><td class="left" csk="6.0" data-stat="war_leader"><a href="/players/w/wangch01.shtml" title="Chien-Ming Wang">C.Wang</a> (6.0)</td><td class="left" data-stat="managers"><a href="/managers/torrejo01.shtml" title="Joe Torre">J.Torre</a> (97-65)</td></tr>
# <tr data-row="20"><th class="left" data-stat="year_ID" scope="row"><a href="/teams/NYY/2005.shtml">2005</a></th><td class="left" data-stat="team_name"><a href="/teams/NYY/2005.shtml">New York Yankees</a></td><td class="left" data-stat="lg_ID"><a href="/leagues/AL/2005.shtml">AL East</a></td><td class="right" data-stat="G">162</td><td class="right" data-stat="W">95</td><td class="right" data-stat="L">67</td><td class="right iz" data-stat="ties">0</td><td class="right" data-stat="win_loss_perc">.586</td><td class="right" data-stat="win_loss_perc_pythag">.553</td><td class="right" csk="1" data-stat="finish">1st of 5</td><td class="right" csk="0.0" data-stat="games_back">--</td><td class="right" csk="4" data-stat="playoffs"><a href="/postseason/2005_ALDS2.shtml">Lost ALDS (3-2)</a></td><td class="right" data-stat="R">886</td><td class="right" data-stat="RA">789</td><td class="right" data-stat="attendance">4,090,696</td><td class="right" data-stat="age_bat">32.4</td><td class="right" data-stat="age_pit">34.2</td><td class="right" data-stat="batters_used">51</td><td class="right" data-stat="pitchers_used">28</td><td class="left" csk="9.4" data-stat="war_leader"><a href="/players/r/rodrial01.shtml" title="Alex Rodriguez">A.Rodriguez</a> (9.4)</td><td class="left" data-stat="managers"><a href="/managers/torrejo01.shtml" title="Joe Torre">J.Torre</a> (95-67)</td></tr>
# <tr data-row="21"><th class="left" data-stat="year_ID" scope="row"><a href="/teams/NYY/2004.shtml">2004</a></th><td class="left" data-stat="team_name"><a href="/teams/NYY/2004.shtml">New York Yankees</a></td><td class="left" data-stat="lg_ID"><a href="/leagues/AL/2004.shtml">AL East</a></td><td class="right" data-stat="G">162</td><td class="right" data-stat="W">101</td><td class="right" data-stat="L">61</td><td class="right iz" data-stat="ties">0</td><td class="right" data-stat="win_loss_perc">.623</td><td class="right" data-stat="win_loss_perc_pythag">.548</td><td class="right" csk="1" data-stat="finish">1st of 5</td><td class="right" csk="0.0" data-stat="games_back">--</td><td class="right" csk="6" data-stat="playoffs"><a href="/postseason/2004_ALCS.shtml">Lost ALCS (4-3)</a></td><td class="right" data-stat="R">897</td><td class="right" data-stat="RA">808</td><td class="right" data-stat="attendance">3,775,292</td><td class="right" data-stat="age_bat">32.3</td><td class="right" data-stat="age_pit">32.9</td><td class="right" data-stat="batters_used">43</td><td class="right" data-stat="pitchers_used">23</td><td class="left" csk="7.6" data-stat="war_leader"><a href="/players/r/rodrial01.shtml" title="Alex Rodriguez">A.Rodriguez</a> (7.6)</td><td class="left" data-stat="managers"><a href="/managers/torrejo01.shtml" title="Joe Torre">J.Torre</a> (101-61)</td></tr>
# <tr data-row="22"><th class="left" data-stat="year_ID" scope="row"><a href="/teams/NYY/2003.shtml">2003</a></th><td class="left" data-stat="team_name"><a href="/teams/NYY/2003.shtml">New York Yankees</a></td><td class="left" data-stat="lg_ID"><a href="/leagues/AL/2003.shtml">AL East</a></td><td class="right" data-stat="G">163</td><td class="right" data-stat="W">101</td><td class="right" data-stat="L">61</td><td class="right" data-stat="ties">1</td><td class="right" data-stat="win_loss_perc">.623</td><td class="right" data-stat="win_loss_perc_pythag">.592</td><td class="right" csk="1" data-stat="finish">1st of 5</td><td class="right" csk="0.0" data-stat="games_back">--</td><td class="right" csk="8" data-stat="playoffs"><a href="/postseason/2003_WS.shtml">Lost WS (4-2)</a></td><td class="right" data-stat="R">877</td><td class="right" data-stat="RA">716</td><td class="right" data-stat="attendance">3,465,600</td><td class="right" data-stat="age_bat">30.4</td><td class="right" data-stat="age_pit">33.7</td><td class="right" data-stat="batters_used">49</td><td class="right" data-stat="pitchers_used">23</td><td class="left" csk="6.5" data-stat="war_leader"><a href="/players/m/mussimi01.shtml" title="Mike Mussina">M.Mussina</a> (6.5)</td><td class="left" data-stat="managers"><a href="/managers/torrejo01.shtml" title="Joe Torre">J.Torre</a> (101-61)</td></tr>
# <tr data-row="23"><th class="left" data-stat="year_ID" scope="row"><a href="/teams/NYY/2002.shtml">2002</a></th><td class="left" data-stat="team_name"><a href="/teams/NYY/2002.shtml">New York Yankees</a></td><td class="left" data-stat="lg_ID"><a href="/leagues/AL/2002.shtml">AL East</a></td><td class="right" data-stat="G">161</td><td class="right" data-stat="W">103</td><td class="right" data-stat="L">58</td><td class="right iz" data-stat="ties">0</td><td class="right" data-stat="win_loss_perc">.640</td><td class="right" data-stat="win_loss_perc_pythag">.613</td><td class="right" csk="1" data-stat="finish">1st of 5</td><td class="right" csk="0.0" data-stat="games_back">--</td><td class="right" csk="4" data-stat="playoffs"><a href="/postseason/2002_ALDS1.shtml">Lost ALDS (3-1)</a></td><td class="right" data-stat="R">897</td><td class="right" data-stat="RA">697</td><td class="right" data-stat="attendance">3,465,807</td><td class="right" data-stat="age_bat">30.0</td><td class="right" data-stat="age_pit">33.1</td><td class="right" data-stat="batters_used">38</td><td class="right" data-stat="pitchers_used">17</td><td class="left" csk="7.1" data-stat="war_leader"><a href="/players/g/giambja01.shtml" title="Jason Giambi">J.Giambi</a> (7.1)</td><td class="left" data-stat="managers"><a href="/managers/torrejo01.shtml" title="Joe Torre">J.Torre</a> (103-58)</td></tr>
# <tr data-row="24"><th class="left" data-stat="year_ID" scope="row"><a href="/teams/NYY/2001.shtml">2001</a></th><td class="left" data-stat="team_name"><a href="/teams/NYY/2001.shtml">New York Yankees</a></td><td class="left" data-stat="lg_ID"><a href="/leagues/AL/2001.shtml">AL East</a></td><td class="right" data-stat="G">161</td><td class="right" data-stat="W">95</td><td class="right" data-stat="L">65</td><td class="right" data-stat="ties">1</td><td class="right" data-stat="win_loss_perc">.594</td><td class="right" data-stat="win_loss_perc_pythag">.555</td><td class="right" csk="1" data-stat="finish">1st of 5</td><td class="right" csk="0.0" data-stat="games_back">--</td><td class="right" csk="8" data-stat="playoffs"><a href="/postseason/2001_WS.shtml">Lost WS (4-3)</a></td><td class="right" data-stat="R">804</td><td class="right" data-stat="RA">713</td><td class="right" data-stat="attendance">3,264,907</td><td class="right" data-stat="age_bat">31.3</td><td class="right" data-stat="age_pit">30.9</td><td class="right" data-stat="batters_used">47</td><td class="right" data-stat="pitchers_used">20</td><td class="left" csk="7.1" data-stat="war_leader"><a href="/players/m/mussimi01.shtml" title="Mike Mussina">M.Mussina</a> (7.1)</td><td class="left" data-stat="managers"><a href="/managers/torrejo01.shtml" title="Joe Torre">J.Torre</a> (95-65)</td></tr>
# <tr class="thead" data-row="25">
# <th aria-label="Year" class="poptip sort_default_asc show_partial_when_sorting left" data-stat="year_ID" data-tip="A Star indicates an all-star that season.&lt;br&gt;A Ring indicates the player appeared in WS for winning team." scope="col">Year</th>
# <th aria-label="Tm" class="poptip sort_default_asc left" data-stat="team_name" scope="col">Tm</th>
# <th aria-label="Lg" class="poptip sort_default_asc center" data-stat="lg_ID" data-tip="&lt;strong&gt;League&lt;/strong&gt;&lt;br&gt; &lt;strong&gt;AL&lt;/strong&gt; - American League (1901-present)&lt;br&gt; &lt;strong&gt;NL&lt;/strong&gt; - National League (1876-present)&lt;br&gt; &lt;strong&gt;AA&lt;/strong&gt; - American Association (1882-1891)&lt;br&gt; &lt;strong&gt;UA&lt;/strong&gt; - Union Association (1884)&lt;br&gt; &lt;strong&gt;PL&lt;/strong&gt; - Players League (1890)&lt;br&gt; &lt;strong&gt;FL&lt;/strong&gt; - Federal League (1914-1915)&lt;br&gt; &lt;strong&gt;NA&lt;/strong&gt; - National Association (1871-1875)&lt;br&gt; &lt;strong&gt;ANL&lt;/strong&gt; - American Negro League (1929)&lt;br&gt; &lt;strong&gt;ECL&lt;/strong&gt; - Eastern Colored League (1923-1928)&lt;br&gt; &lt;strong&gt;EWL&lt;/strong&gt; - East-West League (1932)&lt;br&gt; &lt;strong&gt;NAL&lt;/strong&gt; - Negro American League (1937-1948)&lt;br&gt; &lt;strong&gt;NNL&lt;/strong&gt; - Negro National League (1920-1931)&lt;br&gt; &lt;strong&gt;NN2&lt;/strong&gt; - Negro National League 2 (1933-1948)&lt;br&gt; &lt;strong&gt;NSL&lt;/strong&gt; - Negro Southern League (1932)" scope="col">Lg</th>
# <th aria-label="Games Played" class="poptip center" data-stat="G" data-tip="Games Played or Pitched" scope="col">G</th>
# <th aria-label="Wins" class="poptip center" data-stat="W" data-tip="Wins" scope="col">W</th>
# <th aria-label="Losses" class="poptip center" data-stat="L" data-tip="Losses" scope="col">L</th>
# <th aria-label="Ties" class="poptip center" data-stat="ties" data-tip="&lt;strong&gt;Ties&lt;/strong&gt;&lt;br&gt;Prior to lights and tarps it was common for games&lt;br&gt; to be called on account of darkness or rain&lt;br&gt;and then replayed in full at a later date.&lt;br&gt;Game stats from ties still counted.&lt;br&gt;Some leagues also do not play unlimited numbers of innings." scope="col">Ties</th>
# <th aria-label="Win-Loss %" class="poptip hide_non_quals center" data-filter="1" data-name="Win-Loss %" data-stat="win_loss_perc" data-tip="&lt;strong&gt;Win-Loss Percentage&lt;/strong&gt;&lt;br&gt;W / (W + L)&lt;br&gt;For players, leaders need one decision for every ten team games.&lt;br&gt;For managers, minimum to qualify for leading is 320 games." scope="col">W-L%</th>
# <th aria-label="PythW-L%" class="poptip center" data-filter="1" data-name="PythW-L%" data-stat="win_loss_perc_pythag" data-tip="&lt;strong&gt;Pythagorean Win-Loss Percentage&lt;/strong&gt;&lt;br&gt;This value is an estimate of the teams win-loss percentage&lt;br&gt;based on the runs scored and runs allowed by this team." scope="col">pythW-L%</th>
# <th aria-label="Finish" class="poptip sort_default_asc show_partial_when_sorting center" data-stat="finish" data-tip="Team&amp;#x2019;s Finish&lt;br&gt;For career totals these are the average of all &lt;br&gt;years weighted by the number games played or managed. " scope="col">Finish</th>
# <th aria-label="Games Back" class="poptip sort_default_asc center" data-stat="games_back" data-tip="&lt;strong&gt;Games Back of Division/League Leader&lt;/strong&gt;&lt;br&gt;Computed as games over .500 of leader (W-L) minus games over .500 of team divided by two.&lt;br&gt;Typically computed at the end of play for a particular day.&lt;br&gt;Blank for 1st game of DH." scope="col">GB</th>
# <th aria-label="Playoffs" class="poptip center" data-stat="playoffs" data-tip="&lt;strong&gt;Playoffs&lt;/strong&gt;&lt;br&gt;This shows either the farthest each team went into the postseason&lt;br&gt;or how many postseason appearances in team history." scope="col">Playoffs</th>
# <th aria-label="Runs Scored" class="poptip center" data-stat="R" data-tip="Runs Scored/Allowed" scope="col">R</th>
# <th aria-label="Runs Allowed" class="poptip center" data-stat="RA" data-tip="Runs Allowed" scope="col">RA</th>
# <th aria-label="Attendance" class="poptip center" data-stat="attendance" data-tip="&lt;strong&gt;Attendance&lt;/strong&gt;&lt;br&gt;Typically, tickets sold in home games." scope="col">Attendance</th>
# <th aria-label="BatAge" class="poptip sort_default_asc center" data-stat="age_bat" data-tip="&lt;strong&gt;Batters&amp;#x2019; average age&lt;/strong&gt;&lt;br&gt;Weighted by AB + Games Played" scope="col">BatAge</th>
# <th aria-label="PAge" class="poptip sort_default_asc center" data-stat="age_pit" data-tip="&lt;strong&gt;Pitchers&amp;#x2019; average age&lt;/strong&gt;&lt;br&gt;Weighted by 3*GS + G + SV" scope="col">PAge</th>
# <th aria-label="#Bat" class="poptip center" data-stat="batters_used" data-tip="&lt;strong&gt;Number of Players used in Games&lt;/strong&gt;" scope="col">#Bat</th>
# <th aria-label="#P" class="poptip center" data-stat="pitchers_used" data-tip="&lt;strong&gt;Number of Pitchers used in Games&lt;/strong&gt;" scope="col">#P</th>
# <th aria-label="Top Player" class="poptip center" data-stat="war_leader" data-tip="The team leader for this season in Wins above Replacement" scope="col">Top Player</th>
# <th aria-label="Managers" class="poptip sort_default_asc center" data-stat="managers" scope="col">Managers</th>
# </tr><tr data-row="26"><th class="left" data-stat="year_ID" scope="row"><a href="/teams/NYY/2000.shtml">2000</a></th><td class="left" data-stat="team_name"><a href="/teams/NYY/2000.shtml">New York Yankees</a></td><td class="left" data-stat="lg_ID"><a href="/leagues/AL/2000.shtml">AL East</a></td><td class="right" data-stat="G">161</td><td class="right" data-stat="W">87</td><td class="right" data-stat="L">74</td><td class="right iz" data-stat="ties">0</td><td class="right" data-stat="win_loss_perc">.540</td><td class="right" data-stat="win_loss_perc_pythag">.531</td><td class="right" csk="1" data-stat="finish">1st of 5</td><td class="right" csk="0.0" data-stat="games_back">--</td><td class="right" csk="10" data-stat="playoffs"><strong><a href="/postseason/2000_WS.shtml">Won WS (4-1)</a></strong></td><td class="right" data-stat="R">871</td><td class="right" data-stat="RA">814</td><td class="right" data-stat="attendance">3,055,435</td><td class="right" data-stat="age_bat">31.4</td><td class="right" data-stat="age_pit">32.0</td><td class="right" data-stat="batters_used">46</td><td class="right" data-stat="pitchers_used">22</td><td class="left" csk="5.5" data-stat="war_leader"><a href="/players/p/posadjo01.shtml" title="Jorge Posada">J.Posada</a> (5.5)</td><td class="left" data-stat="managers"><a href="/managers/torrejo01.shtml" title="Joe Torre">J.Torre</a> (87-74)</td></tr>
# ...
# <tr data-row="116"><th class="left" data-stat="year_ID" scope="row"><a href="/teams/NYY/1913.shtml">1913</a></th><td class="left" data-stat="team_name"><a href="/teams/NYY/1913.shtml">New York Yankees</a></td><td class="left" data-stat="lg_ID"><a href="/leagues/AL/1913.shtml">AL</a></td><td class="right" data-stat="G">153</td><td class="right" data-stat="W">57</td><td class="right" data-stat="L">94</td><td class="right" data-stat="ties">2</td><td class="right" data-stat="win_loss_perc">.377</td><td class="right" data-stat="win_loss_perc_pythag">.395</td><td class="right" csk="7" data-stat="finish">7th of 8</td><td class="right" csk="38.0" data-stat="games_back">38.0</td><td class="right iz" csk="0" data-stat="playoffs"></td><td class="right" data-stat="R">529</td><td class="right" data-stat="RA">668</td><td class="right" data-stat="attendance">357,551</td><td class="right" data-stat="age_bat">27.1</td><td class="right" data-stat="age_pit">26.4</td><td class="right" data-stat="batters_used">44</td><td class="right" data-stat="pitchers_used">13</td><td class="left" csk="4.4" data-stat="war_leader"><a href="/players/c/caldwra02.shtml" title="Ray Caldwell">R.Caldwell</a> (4.4)</td><td class="left" data-stat="managers"><a href="/managers/chancfr01.shtml" title="Frank Chance">F.Chance</a> (57-94)</td></tr>
# <tr data-row="117"><th class="left" data-stat="year_ID" scope="row"><a href="/teams/NYY/1912.shtml">1912</a></th><td class="left" data-stat="team_name"><a href="/teams/NYY/1912.shtml">New York Highlanders</a></td><td class="left" data-stat="lg_ID"><a href="/leagues/AL/1912.shtml">AL</a></td><td class="right" data-stat="G">153</td><td class="right" data-stat="W">50</td><td class="right" data-stat="L">102</td><td class="right" data-stat="ties">1</td><td class="right" data-stat="win_loss_perc">.329</td><td class="right" data-stat="win_loss_perc_pythag">.370</td><td class="right" csk="8" data-stat="finish">8th of 8</td><td class="right" csk="55.0" data-stat="games_back">55.0</td><td class="right iz" csk="0" data-stat="playoffs"></td><td class="right" data-stat="R">630</td><td class="right" data-stat="RA">842</td><td class="right" data-stat="attendance">242,194</td><td class="right" data-stat="age_bat">26.7</td><td class="right" data-stat="age_pit">26.7</td><td class="right" data-stat="batters_used">44</td><td class="right" data-stat="pitchers_used">13</td><td class="left" csk="7.1" data-stat="war_leader"><a href="/players/w/warhoja01.shtml" title="Jack Warhop">J.Warhop</a> (7.1)</td><td class="left" data-stat="managers"><a href="/managers/wolveha01.shtml" title="Harry Wolverton">H.Wolverton</a> (50-102)</td></tr>
# <tr data-row="118"><th class="left" data-stat="year_ID" scope="row"><a href="/teams/NYY/1911.shtml">1911</a></th><td class="left" data-stat="team_name"><a href="/teams/NYY/1911.shtml">New York Highlanders</a></td><td class="left" data-stat="lg_ID"><a href="/leagues/AL/1911.shtml">AL</a></td><td class="right" data-stat="G">153</td><td class="right" data-stat="W">76</td><td class="right" data-stat="L">76</td><td class="right" data-stat="ties">1</td><td class="right" data-stat="win_loss_perc">.500</td><td class="right" data-stat="win_loss_perc_pythag">.475</td><td class="right" csk="6" data-stat="finish">6th of 8</td><td class="right" csk="25.5" data-stat="games_back">25.5</td><td class="right iz" csk="0" data-stat="playoffs"></td><td class="right" data-stat="R">684</td><td class="right" data-stat="RA">723</td><td class="right" data-stat="attendance">302,444</td><td class="right" data-stat="age_bat">27.0</td><td class="right" data-stat="age_pit">25.4</td><td class="right" data-stat="batters_used">35</td><td class="right" data-stat="pitchers_used">11</td><td class="left" csk="7.3" data-stat="war_leader"><a href="/players/f/fordru01.shtml" title="Russ Ford">R.Ford</a> (7.3)</td><td class="left" data-stat="managers"><a href="/managers/chaseha01.shtml" title="Hal Chase">H.Chase</a> (76-76)</td></tr>
# <tr data-row="119"><th class="left" data-stat="year_ID" scope="row"><a href="/teams/NYY/1910.shtml">1910</a></th><td class="left" data-stat="team_name"><a href="/teams/NYY/1910.shtml">New York Highlanders</a></td><td class="left" data-stat="lg_ID"><a href="/leagues/AL/1910.shtml">AL</a></td><td class="right" data-stat="G">156</td><td class="right" data-stat="W">88</td><td class="right" data-stat="L">63</td><td class="right" data-stat="ties">5</td><td class="right" data-stat="win_loss_perc">.583</td><td class="right" data-stat="win_loss_perc_pythag">.553</td><td class="right" csk="2" data-stat="finish">2nd of 8</td><td class="right" csk="14.5" data-stat="games_back">14.5</td><td class="right iz" csk="0" data-stat="playoffs"></td><td class="right" data-stat="R">626</td><td class="right" data-stat="RA">557</td><td class="right" data-stat="attendance">355,857</td><td class="right" data-stat="age_bat">27.4</td><td class="right" data-stat="age_pit">25.4</td><td class="right" data-stat="batters_used">31</td><td class="right" data-stat="pitchers_used">10</td><td class="left" csk="11.9" data-stat="war_leader"><a href="/players/f/fordru01.shtml" title="Russ Ford">R.Ford</a> (11.9)</td><td class="left" data-stat="managers"><a href="/managers/stallge01.shtml" title="George Stallings">G.Stallings</a> (78-59) and <a href="/managers/chaseha01.shtml" title="Hal Chase">H.Chase</a> (10-4)</td></tr>
# <tr data-row="120"><th class="left" data-stat="year_ID" scope="row"><a href="/teams/NYY/1909.shtml">1909</a></th><td class="left" data-stat="team_name"><a href="/teams/NYY/1909.shtml">New York Highlanders</a></td><td class="left" data-stat="lg_ID"><a href="/leagues/AL/1909.shtml">AL</a></td><td class="right" data-stat="G">153</td><td class="right" data-stat="W">74</td><td class="right" data-stat="L">77</td><td class="right" data-stat="ties">2</td><td class="right" data-stat="win_loss_perc">.490</td><td class="right" data-stat="win_loss_perc_pythag">.502</td><td class="right" csk="5" data-stat="finish">5th of 8</td><td class="right" csk="23.5" data-stat="games_back">23.5</td><td class="right iz" csk="0" data-stat="playoffs"></td><td class="right" data-stat="R">589</td><td class="right" data-stat="RA">587</td><td class="right" data-stat="attendance">501,000</td><td class="right" data-stat="age_bat">27.8</td><td class="right" data-stat="age_pit">26.5</td><td class="right" data-stat="batters_used">35</td><td class="right" data-stat="pitchers_used">15</td><td class="left" csk="4.4" data-stat="war_leader"><a href="/players/w/warhoja01.shtml" title="Jack Warhop">J.Warhop</a> (4.4)</td><td class="left" data-stat="managers"><a href="/managers/stallge01.shtml" title="George Stallings">G.Stallings</a> (74-77)</td></tr>
# <tr data-row="121"><th class="left" data-stat="year_ID" scope="row"><a href="/teams/NYY/1908.shtml">1908</a></th><td class="left" data-stat="team_name"><a href="/teams/NYY/1908.shtml">New York Highlanders</a></td><td class="left" data-stat="lg_ID"><a href="/leagues/AL/1908.shtml">AL</a></td><td class="right" data-stat="G">155</td><td class="right" data-stat="W">51</td><td class="right" data-stat="L">103</td><td class="right" data-stat="ties">1</td><td class="right" data-stat="win_loss_perc">.331</td><td class="right" data-stat="win_loss_perc_pythag">.310</td><td class="right" csk="8" data-stat="finish">8th of 8</td><td class="right" csk="39.5" data-stat="games_back">39.5</td><td class="right iz" csk="0" data-stat="playoffs"></td><td class="right" data-stat="R">460</td><td class="right" data-stat="RA">713</td><td class="right" data-stat="attendance">305,500</td><td class="right" data-stat="age_bat">28.1</td><td class="right" data-stat="age_pit">28.8</td><td class="right" data-stat="batters_used">32</td><td class="right" data-stat="pitchers_used">14</td><td class="left" csk="3.8" data-stat="war_leader"><a href="/players/h/hemphch01.shtml" title="Charlie Hemphill">C.Hemphill</a> (3.8)</td><td class="left" data-stat="managers"><a href="/managers/griffcl01.shtml" title="Clark Griffith">C.Griffith</a> (24-32) and <a href="/managers/elberki01.shtml" title="Kid Elberfeld">K.Elberfeld</a> (27-71)</td></tr>
# <tr data-row="122"><th class="left" data-stat="year_ID" scope="row"><a href="/teams/NYY/1907.shtml">1907</a></th><td class="left" data-stat="team_name"><a href="/teams/NYY/1907.shtml">New York Highlanders</a></td><td class="left" data-stat="lg_ID"><a href="/leagues/AL/1907.shtml">AL</a></td><td class="right" data-stat="G">152</td><td class="right" data-stat="W">70</td><td class="right" data-stat="L">78</td><td class="right" data-stat="ties">4</td><td class="right" data-stat="win_loss_perc">.473</td><td class="right" data-stat="win_loss_perc_pythag">.455</td><td class="right" csk="5" data-stat="finish">5th of 8</td><td class="right" csk="21.0" data-stat="games_back">21.0</td><td class="right iz" csk="0" data-stat="playoffs"></td><td class="right" data-stat="R">605</td><td class="right" data-stat="RA">667</td><td class="right" data-stat="attendance">350,020</td><td class="right" data-stat="age_bat">28.1</td><td class="right" data-stat="age_pit">29.3</td><td class="right" data-stat="batters_used">33</td><td class="right" data-stat="pitchers_used">17</td><td class="left" csk="5.1" data-stat="war_leader"><a href="/players/c/chesbja01.shtml" title="Jack Chesbro">J.Chesbro</a> (5.1)</td><td class="left" data-stat="managers"><a href="/managers/griffcl01.shtml" title="Clark Griffith">C.Griffith</a> (70-78)</td></tr>
# <tr data-row="123"><th class="left" data-stat="year_ID" scope="row"><a href="/teams/NYY/1906.shtml">1906</a></th><td class="left" data-stat="team_name"><a href="/teams/NYY/1906.shtml">New York Highlanders</a></td><td class="left" data-stat="lg_ID"><a href="/leagues/AL/1906.shtml">AL</a></td><td class="right" data-stat="G">155</td><td class="right" data-stat="W">90</td><td class="right" data-stat="L">61</td><td class="right" data-stat="ties">4</td><td class="right" data-stat="win_loss_perc">.596</td><td class="right" data-stat="win_loss_perc_pythag">.575</td><td class="right" csk="2" data-stat="finish">2nd of 8</td><td class="right" csk="3.0" data-stat="games_back">3.0</td><td class="right iz" csk="0" data-stat="playoffs"></td><td class="right" data-stat="R">640</td><td class="right" data-stat="RA">543</td><td class="right" data-stat="attendance">434,700</td><td class="right" data-stat="age_bat">28.2</td><td class="right" data-stat="age_pit">29.4</td><td class="right" data-stat="batters_used">26</td><td class="right" data-stat="pitchers_used">11</td><td class="left" csk="9.1" data-stat="war_leader"><a href="/players/o/orthal01.shtml" title="Al Orth">A.Orth</a> (9.1)</td><td class="left" data-stat="managers"><a href="/managers/griffcl01.shtml" title="Clark Griffith">C.Griffith</a> (90-61)</td></tr>
# <tr data-row="124"><th class="left" data-stat="year_ID" scope="row"><a href="/teams/NYY/1905.shtml">1905</a></th><td class="left" data-stat="team_name"><a href="/teams/NYY/1905.shtml">New York Highlanders</a></td><td class="left" data-stat="lg_ID"><a href="/leagues/AL/1905.shtml">AL</a></td><td class="right" data-stat="G">152</td><td class="right" data-stat="W">71</td><td class="right" data-stat="L">78</td><td class="right" data-stat="ties">3</td><td class="right" data-stat="win_loss_perc">.477</td><td class="right" data-stat="win_loss_perc_pythag">.473</td><td class="right" csk="6" data-stat="finish">6th of 8</td><td class="right" csk="21.5" data-stat="games_back">21.5</td><td class="right iz" csk="0" data-stat="playoffs"></td><td class="right" data-stat="R">586</td><td class="right" data-stat="RA">621</td><td class="right" data-stat="attendance">309,100</td><td class="right" data-stat="age_bat">29.2</td><td class="right" data-stat="age_pit">29.0</td><td class="right" data-stat="batters_used">35</td><td class="right" data-stat="pitchers_used">11</td><td class="left" csk="5.8" data-stat="war_leader"><a href="/players/o/orthal01.shtml" title="Al Orth">A.Orth</a> (5.8)</td><td class="left" data-stat="managers"><a href="/managers/griffcl01.shtml" title="Clark Griffith">C.Griffith</a> (71-78)</td></tr>
# <tr data-row="125"><th class="left" data-stat="year_ID" scope="row"><a href="/teams/NYY/1904.shtml">1904</a></th><td class="left" data-stat="team_name"><a href="/teams/NYY/1904.shtml">New York Highlanders</a></td><td class="left" data-stat="lg_ID"><a href="/leagues/AL/1904.shtml">AL</a></td><td class="right" data-stat="G">155</td><td class="right" data-stat="W">92</td><td class="right" data-stat="L">59</td><td class="right" data-stat="ties">4</td><td class="right" data-stat="win_loss_perc">.609</td><td class="right" data-stat="win_loss_perc_pythag">.558</td><td class="right" csk="2" data-stat="finish">2nd of 8</td><td class="right" csk="1.5" data-stat="games_back">1.5</td><td class="right iz" csk="0" data-stat="playoffs"></td><td class="right" data-stat="R">598</td><td class="right" data-stat="RA">526</td><td class="right" data-stat="attendance">438,919</td><td class="right" data-stat="age_bat">29.3</td><td class="right" data-stat="age_pit">29.1</td><td class="right" data-stat="batters_used">26</td><td class="right" data-stat="pitchers_used">9</td><td class="left" csk="11.4" data-stat="war_leader"><a href="/players/c/chesbja01.shtml" title="Jack Chesbro">J.Chesbro</a> (11.4)</td><td class="left" data-stat="managers"><a href="/managers/griffcl01.shtml" title="Clark Griffith">C.Griffith</a> (92-59)</td></tr>
# <tr data-row="126"><th class="left" data-stat="year_ID" scope="row"><a href="/teams/NYY/1903.shtml">1903</a></th><td class="left" data-stat="team_name"><a href="/teams/NYY/1903.shtml">New York Highlanders</a></td><td class="left" data-stat="lg_ID"><a href="/leagues/AL/1903.shtml">AL</a></td><td class="right" data-stat="G">136</td><td class="right" data-stat="W">72</td><td class="right" data-stat="L">62</td><td class="right" data-stat="ties">2</td><td class="right" data-stat="win_loss_perc">.537</td><td class="right" data-stat="win_loss_perc_pythag">.505</td><td class="right" csk="4" data-stat="finish">4th of 8</td><td class="right" csk="17.0" data-stat="games_back">17.0</td><td class="right iz" csk="0" data-stat="playoffs"></td><td class="right" data-stat="R">579</td><td class="right" data-stat="RA">573</td><td class="right" data-stat="attendance">211,808</td><td class="right" data-stat="age_bat">29.0</td><td class="right" data-stat="age_pit">28.5</td><td class="right" data-stat="batters_used">28</td><td class="right" data-stat="pitchers_used">11</td><td class="left" csk="4.9" data-stat="war_leader"><a href="/players/c/chesbja01.shtml" title="Jack Chesbro">J.Chesbro</a> (4.9)</td><td class="left" data-stat="managers"><a href="/managers/griffcl01.shtml" title="Clark Griffith">C.Griffith</a> (72-62)</td></tr>
# </tbody></table>

# %%
def _extract_table(table):
    trs = table.tbody.find_all("tr")
    row_data = {}
    for tr in trs:
        if tr.has_attr("class") and "thead" in tr["class"]:
            continue
        tds = tr.find_all("th")
        tds.extend(tr.find_all("td"))
        if len(tds) == 0:
            continue
        for td in tds:
            data_stat = td.attrs["data-stat"]
            if data_stat not in row_data:
                row_data[data_stat] = []
            if td.find("a"):
                row_data[data_stat].append(td.find("a").text)
            elif td.find("span"):
                row_data[data_stat].append(td.find("span").string)
            elif td.find("strong"):
                row_data[data_stat].append(td.find("strong").string)
            else:
                row_data[data_stat].append(td.string)
    return row_data

# %%
import polars as pl

# %%
df = pl.DataFrame(_extract_table(franch_history_table))

# %%
df
# Out:
# shape: (123, 21)
# ┌─────────┬──────────────┬─────────┬─────┬───┬─────────────┬─────────────┬────────────┬────────────┐
# │ year_ID ┆ team_name    ┆ lg_ID   ┆ G   ┆ … ┆ batters_use ┆ pitchers_us ┆ war_leader ┆ managers   │
# │ ---     ┆ ---          ┆ ---     ┆ --- ┆   ┆ d           ┆ ed          ┆ ---        ┆ ---        │
# │ str     ┆ str          ┆ str     ┆ str ┆   ┆ ---         ┆ ---         ┆ str        ┆ str        │
# │         ┆              ┆         ┆     ┆   ┆ str         ┆ str         ┆            ┆            │
# ╞═════════╪══════════════╪═════════╪═════╪═══╪═════════════╪═════════════╪════════════╪════════════╡
# │ 2025    ┆ New York Yan ┆ AL East ┆ 132 ┆ … ┆ 52          ┆ 33          ┆ A.Judge    ┆ A.Boone    │
# │         ┆ kees         ┆         ┆     ┆   ┆             ┆             ┆            ┆            │
# │ 2024    ┆ New York Yan ┆ AL East ┆ 162 ┆ … ┆ 54          ┆ 33          ┆ A.Judge    ┆ A.Boone    │
# │         ┆ kees         ┆         ┆     ┆   ┆             ┆             ┆            ┆            │
# │ 2023    ┆ New York Yan ┆ AL East ┆ 162 ┆ … ┆ 54          ┆ 32          ┆ G.Cole     ┆ A.Boone    │
# │         ┆ kees         ┆         ┆     ┆   ┆             ┆             ┆            ┆            │
# │ 2022    ┆ New York Yan ┆ AL East ┆ 162 ┆ … ┆ 54          ┆ 33          ┆ A.Judge    ┆ A.Boone    │
# │         ┆ kees         ┆         ┆     ┆   ┆             ┆             ┆            ┆            │
# │ 2021    ┆ New York Yan ┆ AL East ┆ 162 ┆ … ┆ 59          ┆ 30          ┆ A.Judge    ┆ A.Boone    │
# │         ┆ kees         ┆         ┆     ┆   ┆             ┆             ┆            ┆            │
# │ …       ┆ …            ┆ …       ┆ …   ┆ … ┆ …           ┆ …           ┆ …          ┆ …          │
# │ 1907    ┆ New York Hig ┆ AL      ┆ 152 ┆ … ┆ 33          ┆ 17          ┆ J.Chesbro  ┆ C.Griffith │
# │         ┆ hlanders     ┆         ┆     ┆   ┆             ┆             ┆            ┆            │
# │ 1906    ┆ New York Hig ┆ AL      ┆ 155 ┆ … ┆ 26          ┆ 11          ┆ A.Orth     ┆ C.Griffith │
# │         ┆ hlanders     ┆         ┆     ┆   ┆             ┆             ┆            ┆            │
# │ 1905    ┆ New York Hig ┆ AL      ┆ 152 ┆ … ┆ 35          ┆ 11          ┆ A.Orth     ┆ C.Griffith │
# │         ┆ hlanders     ┆         ┆     ┆   ┆             ┆             ┆            ┆            │
# │ 1904    ┆ New York Hig ┆ AL      ┆ 155 ┆ … ┆ 26          ┆ 9           ┆ J.Chesbro  ┆ C.Griffith │
# │         ┆ hlanders     ┆         ┆     ┆   ┆             ┆             ┆            ┆            │
# │ 1903    ┆ New York Hig ┆ AL      ┆ 136 ┆ … ┆ 28          ┆ 11          ┆ J.Chesbro  ┆ C.Griffith │
# │         ┆ hlanders     ┆         ┆     ┆   ┆             ┆             ┆            ┆            │
# └─────────┴──────────────┴─────────┴─────┴───┴─────────────┴─────────────┴────────────┴────────────┘

# %%
df = df.with_columns(
    [
        pl.col(
            [
                "G",
                "W",
                "L",
                "ties",
                "R",
                "RA",
                "batters_used",
                "pitchers_used",
                "year_ID",
            ]
        ).cast(pl.Int16),
        pl.col(
            [
                "win_loss_perc",
                "win_loss_perc_pythag",
                "age_bat",
                "age_pit",
            ]
        ).cast(pl.Float32),
    ]
)
df.head()
# Out:
# shape: (5, 21)
# ┌─────────┬──────────────┬─────────┬─────┬───┬──────────────┬──────────────┬────────────┬──────────┐
# │ year_ID ┆ team_name    ┆ lg_ID   ┆ G   ┆ … ┆ batters_used ┆ pitchers_use ┆ war_leader ┆ managers │
# │ ---     ┆ ---          ┆ ---     ┆ --- ┆   ┆ ---          ┆ d            ┆ ---        ┆ ---      │
# │ i16     ┆ str          ┆ str     ┆ i16 ┆   ┆ i16          ┆ ---          ┆ str        ┆ str      │
# │         ┆              ┆         ┆     ┆   ┆              ┆ i16          ┆            ┆          │
# ╞═════════╪══════════════╪═════════╪═════╪═══╪══════════════╪══════════════╪════════════╪══════════╡
# │ 2025    ┆ New York Yan ┆ AL East ┆ 132 ┆ … ┆ 52           ┆ 33           ┆ A.Judge    ┆ A.Boone  │
# │         ┆ kees         ┆         ┆     ┆   ┆              ┆              ┆            ┆          │
# │ 2024    ┆ New York Yan ┆ AL East ┆ 162 ┆ … ┆ 54           ┆ 33           ┆ A.Judge    ┆ A.Boone  │
# │         ┆ kees         ┆         ┆     ┆   ┆              ┆              ┆            ┆          │
# │ 2023    ┆ New York Yan ┆ AL East ┆ 162 ┆ … ┆ 54           ┆ 32           ┆ G.Cole     ┆ A.Boone  │
# │         ┆ kees         ┆         ┆     ┆   ┆              ┆              ┆            ┆          │
# │ 2022    ┆ New York Yan ┆ AL East ┆ 162 ┆ … ┆ 54           ┆ 33           ┆ A.Judge    ┆ A.Boone  │
# │         ┆ kees         ┆         ┆     ┆   ┆              ┆              ┆            ┆          │
# │ 2021    ┆ New York Yan ┆ AL East ┆ 162 ┆ … ┆ 59           ┆ 30           ┆ A.Judge    ┆ A.Boone  │
# │         ┆ kees         ┆         ┆     ┆   ┆              ┆              ┆            ┆          │
# └─────────┴──────────────┴─────────┴─────┴───┴──────────────┴──────────────┴────────────┴──────────┘

# %%
df = df.with_columns(pl.col("games_back").str.replace("--", "0").cast(pl.Float32))
df.head()
# Out:
# shape: (5, 21)
# ┌─────────┬──────────────┬─────────┬─────┬───┬──────────────┬──────────────┬────────────┬──────────┐
# │ year_ID ┆ team_name    ┆ lg_ID   ┆ G   ┆ … ┆ batters_used ┆ pitchers_use ┆ war_leader ┆ managers │
# │ ---     ┆ ---          ┆ ---     ┆ --- ┆   ┆ ---          ┆ d            ┆ ---        ┆ ---      │
# │ i16     ┆ str          ┆ str     ┆ i16 ┆   ┆ i16          ┆ ---          ┆ str        ┆ str      │
# │         ┆              ┆         ┆     ┆   ┆              ┆ i16          ┆            ┆          │
# ╞═════════╪══════════════╪═════════╪═════╪═══╪══════════════╪══════════════╪════════════╪══════════╡
# │ 2025    ┆ New York Yan ┆ AL East ┆ 132 ┆ … ┆ 52           ┆ 33           ┆ A.Judge    ┆ A.Boone  │
# │         ┆ kees         ┆         ┆     ┆   ┆              ┆              ┆            ┆          │
# │ 2024    ┆ New York Yan ┆ AL East ┆ 162 ┆ … ┆ 54           ┆ 33           ┆ A.Judge    ┆ A.Boone  │
# │         ┆ kees         ┆         ┆     ┆   ┆              ┆              ┆            ┆          │
# │ 2023    ┆ New York Yan ┆ AL East ┆ 162 ┆ … ┆ 54           ┆ 32           ┆ G.Cole     ┆ A.Boone  │
# │         ┆ kees         ┆         ┆     ┆   ┆              ┆              ┆            ┆          │
# │ 2022    ┆ New York Yan ┆ AL East ┆ 162 ┆ … ┆ 54           ┆ 33           ┆ A.Judge    ┆ A.Boone  │
# │         ┆ kees         ┆         ┆     ┆   ┆              ┆              ┆            ┆          │
# │ 2021    ┆ New York Yan ┆ AL East ┆ 162 ┆ … ┆ 59           ┆ 30           ┆ A.Judge    ┆ A.Boone  │
# │         ┆ kees         ┆         ┆     ┆   ┆              ┆              ┆            ┆          │
# └─────────┴──────────────┴─────────┴─────┴───┴──────────────┴──────────────┴────────────┴──────────┘
